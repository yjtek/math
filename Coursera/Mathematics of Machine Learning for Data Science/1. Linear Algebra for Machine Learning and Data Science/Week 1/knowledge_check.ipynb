# %% [markdown]
# We want your learning experience to be as efficient as possible. If you already know some linear algebra you might be able to skip some of the lectures in this course. Have a look at the questions below. If you already know how to answer them you can feel free skip the videos listed in parentheses
#
# Note: There are two quizzes in this week. The quiz at the end of the first lesson is an ungraded practice quiz and its score does not count towards the total score of the course. The quiz at the end of the second lesson is a graded summative quiz and its score does count towards the total score of the course.
#
#
# 1. Translate the following description into a system of linear equations: Bob has a mixture of apples and oranges of the same size, which he split into two bags. The first bag contains 4 apples and 3 oranges and weighs 700g. The second bag contains 2 apples and 6 oranges and weighs 1000g.
#
# $$
# \begin{bmatrix}
#     4 & 3 \\
#     2 & 6
# \end{bmatrix} \cdot
# \begin{bmatrix}
#     \text{apple} \\
#     \text{orange}
# \end{bmatrix} =
# \begin{bmatrix}
#     700 \\
#     1000
# \end{bmatrix}
# $$
#
# 2. Translate the following system of linear equations into the matrix form
# ​
# $$
# \begin{bmatrix}
#     5 & 3 & 5 \\
#     7 & 2 & 8 \\
#     4 & 0 & 3
# \end{bmatrix} \cdot
# \begin{bmatrix}
#     x \\
#     y \\
#     z
# \end{bmatrix} =
# \begin{bmatrix}
#     6 \\
#     17 \\
#     8
# \end{bmatrix}
# $$
#
# $$
#     5x+3y+5z=6 \\
#     7x+2y+8z=17 \\
#     4x+3z=8
# $$
#
# 3. Compute the determinant of the following matrix
# $
# \begin{align}
#     1 * (3*8 - 5*3) - 2 * (0*8 - 4*5) + 1 * (0*3 - 3*4) = 37
# \end{align}
# $
# ​
# $$
# \begin{bmatrix}
#     1 & 2 & 1 \\
#     0 & 3 & 5 \\
#     4 & 3 & 8
# \end{bmatrix}
# $$
#
# 4. Does the matrix above have any linear dependent row? (Videos:  Linear Dependence and Independence, Linear Dependence and Independence (3x3))
#     - No
#
#
# 5. Is the matrix singular or non singular? (Videos: A geometric notion of singularity, Singular vs Nonsingular matrices, Singular vs Nonsingular matrices (3x3))
#     - Not singular
